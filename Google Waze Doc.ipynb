# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\hjhum\Projects\google-capstone-waze\waze_dataset.csv")

# %%
df.head()
# Out:
#    ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0   0  retained       283     226      296.748273                     2276
# 1   1  retained       133     107      326.896596                     1225
# 2   2  retained       114      95      135.522926                     2651
# 3   3  retained        49      40       67.589221                       15
# 4   4  retained        84      68      168.247020                     1562
#
#    total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                     208                       0       2628.845068
# 1                      19                      64      13715.920550
# 2                       0                       0       3059.148818
# 3                     322                       7        913.591123
# 4                     166                       5       3950.202008
#
#    duration_minutes_drives  activity_days  driving_days   device
# ...

# %%
df.size
# Out:
# 194987

# %%
df.describe()
# Out:
#                  ID      sessions        drives  total_sessions  \
# count  14999.000000  14999.000000  14999.000000    14999.000000
# mean    7499.000000     80.633776     67.281152      189.964447
# std     4329.982679     80.699065     65.913872      136.405128
# min        0.000000      0.000000      0.000000        0.220211
# 25%     3749.500000     23.000000     20.000000       90.661156
# 50%     7499.000000     56.000000     48.000000      159.568115
# 75%    11248.500000    112.000000     93.000000      254.192341
# max    14998.000000    743.000000    596.000000     1216.154633
#
#        n_days_after_onboarding  total_navigations_fav1  \
# count             14999.000000            14999.000000
# mean               1749.837789              121.605974
# std                1008.513876              148.121544
# min                   4.000000                0.000000
# 25%                 878.000000                9.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       14999 non-null  int64
#  1   label                    14299 non-null  object
#  2   sessions                 14999 non-null  int64
#  3   drives                   14999 non-null  int64
#  4   total_sessions           14999 non-null  float64
#  5   n_days_after_onboarding  14999 non-null  int64
#  6   total_navigations_fav1   14999 non-null  int64
#  7   total_navigations_fav2   14999 non-null  int64
#  8   driven_km_drives         14999 non-null  float64
#  9   duration_minutes_drives  14999 non-null  float64
#  10  activity_days            14999 non-null  int64
#  11  driving_days             14999 non-null  int64
#  12  device                   14999 non-null  object
# dtypes: float64(3), int64(8), object(2)
# memory usage: 1.5+ MB

# %%
plt.boxplot(df["sessions"])

plt.title("Distribution of Monthly User Sessions")
plt.ylabel("Sessions per User per Month")
plt.grid(axis="y")

plt.show()

# %%
sns.set_theme(style="whitegrid", context="talk", palette="Set2")

# %%
plt.hist(df["sessions"]) 

plt.title("Histogram of Monthly User Sessions") 
plt.xlabel("Sessions per User per Month") 
plt.ylabel("Number of Users") 
plt.grid(axis="y") 

plt.show()

# %%
plt.boxplot(df["drives"])

plt.title("Distribution of monthly drives")
plt.ylabel("Drives 1km+ per Month")
plt.grid(axis="y")

plt.show()

# %%
plt.hist(df["drives"])

plt.title("Histogram of Monthly Drives")
plt.xlabel("Drives of 1km+ per Month")
plt.ylabel("Number of Users")
plt.grid(axis="y")

plt.show()

# %%
plt.boxplot(df["total_sessions"])

plt.title("Total Sessions Since Onboarding")
plt.ylabel("Sessions Since Onboarding")
plt.grid(axis="y")

plt.show()

# %%
plt.hist(df["total_sessions"])

plt.title("Histogram of Total Sessions Since Onboarding")
plt.xlabel("Sessions Since Onboarding")
plt.ylabel("Number of Users")
plt.grid(axis="y")

plt.show()

# %%
plt.boxplot(df["n_days_after_onboarding"])

plt.title("Number of Days Since Sign-Up")
plt.ylabel("Number of Days")
plt.grid(axis="y")

plt.show()

# %%
plt.hist(df["n_days_after_onboarding"])

plt.title("Histogram of Number of Days Since Onboarding")
plt.xlabel("Days Since Onboarding")
plt.ylabel("Number of Users")
plt.grid(axis="y")

plt.show()

# %%
plt.boxplot(df["driven_km_drives"])

plt.title("Total Kilometers Driven Per Month")
plt.ylabel("Total KM")
plt.grid(axis="y")

plt.show()

# %%
plt.hist(df["driven_km_drives"])

plt.title("Histogram of Total KM Driven Per User")
plt.xlabel("Total KM Driven")
plt.ylabel("Number of Users")
plt.grid(axis="y")

plt.show()

# %%
plt.boxplot(df["duration_minutes_drives"])

plt.title("Total Duration (in Minutes) Driven Per Month")
plt.ylabel("Total Minutes")
plt.grid(axis="y")

plt.show()

# %%
plt.hist(df["duration_minutes_drives"])

plt.title("Histogram of Total Minutes Driven Per User")
plt.xlabel("Total Minutes Driven")
plt.ylabel("Number of Users")
plt.grid(axis="y")

plt.show()

# %%
plt.boxplot(df["activity_days"])

plt.title("Total Days of Activity in App")
plt.ylabel("Total Days of Activity")
plt.grid(axis="y")

plt.show()

# %%
plt.hist(df["activity_days"])

plt.title("Histogram of Total Monthly Active Days Per User")
plt.xlabel("Total Days Active")
plt.ylabel("Number of Users")
plt.grid(axis="y")

plt.show()

# %%
plt.boxplot(df["driving_days"])

plt.title("Total Driving Days Per Month (1km plus drives)")
plt.ylabel("Total Driving Days")
plt.grid(axis="y")

plt.show()

# %%
plt.hist(df["driving_days"])

plt.title("Histogram of Total Driving Days Per User")
plt.xlabel("Total Driving Days")
plt.ylabel("Number of Users")
plt.grid(axis="y")

plt.show()

# %%
counts = df["device"].value_counts()
print(counts)
# Out:
# device
# iPhone     9672
# Android    5327
# Name: count, dtype: int64

# %%
percentages = counts / counts.sum() * 100
print(percentages)
# Out:
# device
# iPhone     64.484299
# Android    35.515701
# Name: count, dtype: float64

# %%
plt.pie(
    counts
)

plt.title("Device Type")
plt.axis("equal")

plt.show()

# %%
plt.pie(
    counts,
    labels=counts.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Device Type")
plt.axis("equal")

plt.show()

# %%
label_count = df["label"].value_counts()
print(label_count)
# Out:
# label
# retained    11763
# churned      2536
# Name: count, dtype: int64

# %%
percentages_label = label_count / label_count.sum() * 100
print(percentages_label)
# Out:
# label
# retained    82.264494
# churned     17.735506
# Name: count, dtype: float64

# %%
plt.pie(
    percentages_label,
    labels=percentages_label.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Churned vs. Retained")
plt.axis("equal")

plt.show()

# %%
plt.hist(
    df["driving_days"],
    label="Driving Days"
)

plt.hist(
    df["activity_days"],
    label="Activity Days"
)

plt.xlabel("Number of Days")
plt.ylabel("Count")
plt.title("Distribution of Driving Days vs Activity Days")
plt.legend()

plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    df["driving_days"],
    bins=20,
    alpha=0.6,
    label="Driving Days"
)

plt.hist(
    df["activity_days"],
    bins=20,
    alpha=0.6,
    label="Activity Days"
)

plt.xlabel("Number of Days")
plt.ylabel("Count")
plt.title("Distribution of Driving Days vs Activity Days Per Month")
plt.legend()

plt.show()

# %%
df.loc[df["driving_days"].idxmax()]
# Out:
# ID                                         1817
# label                                  retained
# sessions                                      1
# drives                                        1
# total_sessions                       183.707658
# n_days_after_onboarding                    2653
# total_navigations_fav1                      577
# total_navigations_fav2                        0
# driven_km_drives                     1503.54192
# duration_minutes_drives             1189.611878
# activity_days                                31
# driving_days                                 30
# device                                   iPhone
# km_per_driving_day                    50.118064
# percent_sessions_in_last_month         0.005443
# monthly_drives_per_session_ratio            1.0
# Name: 1817, dtype: object

# %%
df.loc[df["activity_days"].idxmax()]
# Out:
# ID                                           30
# label                                  retained
# sessions                                     78
# drives                                       66
# total_sessions                       454.363204
# n_days_after_onboarding                    2381
# total_navigations_fav1                      106
# total_navigations_fav2                       21
# driven_km_drives                    8889.794236
# duration_minutes_drives             4668.899349
# activity_days                                31
# driving_days                                 26
# device                                   iPhone
# km_per_driving_day                   406.654607
# percent_sessions_in_last_month         0.160967
# monthly_drives_per_session_ratio       0.846154
# Name: 30, dtype: object

# %%
plt.scatter(
    df["activity_days"],
    df["driving_days"]
)

plt.xlabel("Activity Days")
plt.ylabel("Driving Days")
plt.title("Scatter Plot of Activity Days vs. Driving Days")

plt.show()

# %%
device_label_counts = df.groupby(["device", "label"]).size()
print(device_label_counts)
# Out:
# device   label
# Android  churned      891
#          retained    4183
# iPhone   churned     1645
#          retained    7580
# dtype: int64

# %%
plt.figure()

device_label_counts.plot(kind="bar")

plt.xlabel("Device and Label")
plt.ylabel("Number of Users")
plt.title("User Retention by Device Type")

plt.show()

# %%
df["km_per_driving_day"] = df['driven_km_drives'] / df['driving_days']

# %%
df["km_per_driving_day"].describe()
# Out:
# c:\Users\hjhum\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# count    1.499900e+04
# mean              inf
# std               NaN
# min      3.022063e+00
# 25%      1.672804e+02
# 50%      3.226746e+02
# 75%      7.370429e+02
# max               inf
# Name: km_per_driving_day, dtype: float64

# %%
df.loc[df['km_per_driving_day']==np.inf, 'km_per_driving_day'] = 0
df['km_per_driving_day'].describe()
# Out:
# count    14999.000000
# mean       564.332421
# std        963.973921
# min          0.000000
# 25%        136.238895
# 50%        272.889272
# 75%        542.953671
# max       8889.794236
# Name: km_per_driving_day, dtype: float64

# %%
import seaborn as sns
plt.figure(figsize=(12,5))
sns.histplot(data=df,
             x='km_per_driving_day',
             bins=range(0,1201,20),
             hue='label',
             multiple='fill')
plt.ylabel('%', rotation=0)
plt.title('Churn rate by mean km per driving day');

# %%
sns.set_theme(style="whitegrid", context="talk")

plt.figure(figsize=(12, 5))

sns.histplot(
    data=df,
    x="km_per_driving_day",
    bins=range(0, 1201, 20),
    hue="label",
    multiple="fill",
    palette="Set2",
    edgecolor="white"
)

plt.xlabel("Mean km per driving day")
plt.ylabel("Proportion", rotation=0, labelpad=40)
plt.title("Churn Rate by Mean km per Driving Day")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.histplot(data=df,
             x='driving_days',
             bins=range(1,32),
             hue='label',
             multiple='fill',
             discrete=True)
plt.ylabel('%', rotation=0)
plt.title('Churn rate per driving day');

# %%
sns.set_theme(style="whitegrid", context="talk")

plt.figure(figsize=(12, 5))

sns.histplot(
    data=df,
    x="driving_days",
    bins=range(1, 32),
    hue="label",
    multiple="fill",
    discrete=True,
    palette="Set2",
    edgecolor="white"
)

plt.xlabel("Driving days per month")
plt.ylabel("Proportion", rotation=0, labelpad=40)
plt.title("Churn Rate by Driving Days")

plt.tight_layout()
plt.show()

# %%
df['percent_sessions_in_last_month'] = df['sessions'] / df['total_sessions']
df['percent_sessions_in_last_month'].describe()
# Out:
# count    14999.000000
# mean         0.443563
# std          0.278569
# min          0.000000
# 25%          0.199616
# 50%          0.427184
# 75%          0.664844
# max          1.530637
# Name: percent_sessions_in_last_month, dtype: float64

# %%
df['percent_sessions_in_last_month'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 14999 entries, 0 to 14998
# Series name: percent_sessions_in_last_month
# Non-Null Count  Dtype
# --------------  -----
# 14999 non-null  float64
# dtypes: float64(1)
# memory usage: 117.3 KB

# %%
df['percent_sessions_in_last_month'].head()
# Out:
# 0    0.818876
# 1    0.406856
# 2    0.841186
# 3    0.724968
# 4    0.499266
# Name: percent_sessions_in_last_month, dtype: float64

# %%
def histogrammer(
    x,
    hue=None,
    data=df,
    bins=20,
    multiple="layer",
    median_text=True,
    figsize=(12, 5)
):
    plt.figure(figsize=figsize)

    sns.histplot(
        data=data,
        x=x,
        hue=hue,
        bins=bins,
        multiple=multiple,
        edgecolor="white"
    )

    if median_text:
        med = data[x].median()
        plt.axvline(med, linestyle="--")
        plt.text(
            med,
            plt.ylim()[1] * 0.9,
            f"Median: {med:.2f}",
            ha="right"
        )

    plt.xlabel(x.replace("_", " ").title())
    plt.ylabel("Count")
    plt.title(f"Distribution of {x.replace('_', ' ').title()}")

    plt.tight_layout()
    plt.show()

# %%
histogrammer(
    x="percent_sessions_in_last_month",
    hue="label",
    multiple="layer",
    median_text=False
)

# %%
df['n_days_after_onboarding'].describe()
# Out:
# count    14999.000000
# mean      1749.837789
# std       1008.513876
# min          4.000000
# 25%        878.000000
# 50%       1741.000000
# 75%       2623.500000
# max       3500.000000
# Name: n_days_after_onboarding, dtype: float64

# %%
data = df.loc[df['percent_sessions_in_last_month']>=0.4]
plt.figure(figsize=(5,3))
sns.histplot( x=data['n_days_after_onboarding'],
    edgecolor="white")
plt.title('Num. days after onboarding for users with >=40% sessions in last month');

# %%
sns.set_theme(style="whitegrid", context="talk", palette="Set2")

data = df[df["percent_sessions_in_last_month"] >= 0.4]

plt.figure(figsize=(8, 4))

sns.histplot(
    data=data,
    x="n_days_after_onboarding",
    edgecolor="white",
    color=sns.color_palette("Set2")[0]
)

plt.xlabel("Days After Onboarding")
plt.ylabel("Number of Users")
plt.title("Days After Onboarding for Users with ≥ 40% Sessions Last Month")

plt.tight_layout()
plt.show()

# %%
def outlier_imputer(column_name, percentile):
    # Calculate threshold
    threshold = df[column_name].quantile(percentile)
    # Impute threshold for values > than threshold
    df.loc[df[column_name] > threshold, column_name] = threshold

    print('{:>25} | percentile: {} | threshold: {}'.format(column_name, percentile, threshold))

# %%
for column in ['sessions', 'drives', 'total_sessions',
               'driven_km_drives', 'duration_minutes_drives']:
               outlier_imputer(column, 0.95)
# Out:
#                  sessions | percentile: 0.95 | threshold: 243.0
#                    drives | percentile: 0.95 | threshold: 201.0
#            total_sessions | percentile: 0.95 | threshold: 454.34351188399995
#          driven_km_drives | percentile: 0.95 | threshold: 8889.77766066
#   duration_minutes_drives | percentile: 0.95 | threshold: 4668.8217213

# %%
df.describe()
# Out:
#                  ID      sessions        drives  total_sessions  \
# count  14999.000000  14999.000000  14999.000000    14999.000000
# mean    7499.000000     76.568705     64.058204      184.030336
# std     4329.982679     67.297958     55.306924      118.598218
# min        0.000000      0.000000      0.000000        0.220211
# 25%     3749.500000     23.000000     20.000000       90.661156
# 50%     7499.000000     56.000000     48.000000      159.568115
# 75%    11248.500000    112.000000     93.000000      254.192341
# max    14998.000000    243.000000    201.000000      454.343512
#
#        n_days_after_onboarding  total_navigations_fav1  \
# count             14999.000000            14999.000000
# mean               1749.837789              121.605974
# std                1008.513876              148.121544
# min                   4.000000                0.000000
# 25%                 878.000000                9.000000
# ...

# %%
df['monthly_drives_per_session_ratio'] = (df['drives']/df['sessions'])

# %%
df.head(10)
# Out:
#    ID     label  sessions  drives  total_sessions  n_days_after_onboarding  \
# 0   0  retained       243     201      296.748273                     2276
# 1   1  retained       133     107      326.896596                     1225
# 2   2  retained       114      95      135.522926                     2651
# 3   3  retained        49      40       67.589221                       15
# 4   4  retained        84      68      168.247020                     1562
# 5   5  retained       113     103      279.544437                     2637
# 6   6  retained         3       2      236.725314                      360
# 7   7  retained        39      35      176.072845                     2999
# 8   8  retained        57      46      183.532018                      424
# 9   9   churned        84      68      244.802115                     2997
#
#    total_navigations_fav1  total_navigations_fav2  driven_km_drives  \
# 0                     208                       0       2628.845068
# ...

# %%
df['monthly_drives_per_session_ratio'].describe()
# Out:
# count    14894.000000
# mean         0.860566
# std          0.077298
# min          0.000000
# 25%          0.805263
# 50%          0.826087
# 75%          0.900000
# max          1.000000
# Name: monthly_drives_per_session_ratio, dtype: float64

# %%
sns.set_theme(style="whitegrid", context="talk", palette="Set2")

plt.figure(figsize=(10, 5))

sns.histplot(
    data=df,
    x="monthly_drives_per_session_ratio",
    hue="label",
    bins=20,
    multiple="layer",   # overlap distributions
    edgecolor="white"
)

plt.xlabel("Monthly Drives per Session")
plt.ylabel("Number of Users")
plt.title("Distribution of Monthly Drives per Session Ratio by User Label")

plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid", context="talk", palette="Set2")

plt.figure(figsize=(10, 5))

sns.histplot(
    data=df,
    x="n_days_after_onboarding",
    hue="label",
    bins=20,
    multiple="layer",
    edgecolor="white"
)

plt.xlabel("Days After Onboarding")
plt.ylabel("Number of Users")
plt.title("Days After Onboarding by Churn Label")

plt.tight_layout()
plt.show()

# %%
#Churned users are more heavily represented among users with fewer days since onboarding, 
# while retained users are more common in users who have a longer app history.

# %%
df.to_csv("waze_dataset_cleaned.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\hjhum\\Projects\\google-capstone-waze'
